# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
array_2d = np.loadtxt('./hydro_info_1/initial.txt')

# 绘制热力图
plt.imshow(array_2d, cmap='hot', interpolation='nearest')
plt.colorbar() 
plt.title('2D Distribution Heatmap')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()
